# %%
from extract_data import extract_data
import pandas as pd

# %%
data_dir = extract_data()
datas_dict = {key:pd.read_csv(path) for key,path in data_dir.items()}

# %%
for data in list(datas_dict.values()):
    print(data)
# Out:
#          ID1    AB_Flow  BA_Flow   Tot_Flow   AB_Time  BA_Time  Max_Time  \
# 0          1    68.4000      NaN    68.4000  2.155190      NaN  2.155190
# 1          2  2104.1566      NaN  2104.1566  0.235936      NaN  0.235936
# 2          3   549.0655      NaN   549.0655  0.488676      NaN  0.488676
# 3          4   723.6655      NaN   723.6655  0.108195      NaN  0.108195
# 4          5   723.6655      NaN   723.6655  0.239854      NaN  0.239854
# ...      ...        ...      ...        ...       ...      ...       ...
# 10842  17993   715.2000     54.0   769.2000  3.126930  3.12672  3.126930
# 10843  17995     0.0000      0.0     0.0000  4.491600  4.49160  4.491600
# 10844  17997     0.0000      0.0     0.0000  4.196940  4.19694  4.196940
# 10845  17999     0.0000      0.0     0.0000  3.865860  3.86586  3.865860
# 10846  18001   206.4000    694.8   901.2000  3.545760  3.54597  3.545970
#
#          AB_VOC    BA_VOC   Max_VOC  ...   BA_VKmT  Tot_VKmT    AB_VHT  \
# ...

# %%
data1[data1['BA_VKmT'].isnull()]
# Out:
#        ID1    AB_Flow  BA_Flow   Tot_Flow   AB_Time  BA_Time  Max_Time  \
# 0        1    68.4000      NaN    68.4000  2.155190      NaN  2.155190
# 1        2  2104.1566      NaN  2104.1566  0.235936      NaN  0.235936
# 2        3   549.0655      NaN   549.0655  0.488676      NaN  0.488676
# 3        4   723.6655      NaN   723.6655  0.108195      NaN  0.108195
# 4        5   723.6655      NaN   723.6655  0.239854      NaN  0.239854
# ...    ...        ...      ...        ...       ...      ...       ...
# 6049  8412   217.2000      NaN   217.2000  0.026582      NaN  0.026582
# 6051  8415   633.2882      NaN   633.2882  0.150446      NaN  0.150446
# 6052  8416     0.0000      NaN     0.0000  0.024675      NaN  0.024675
# 6053  8417  2173.9626      NaN  2173.9626  0.101187      NaN  0.101187
# 6054  8418   802.8655      NaN   802.8655  0.358607      NaN  0.358607
#
#         AB_VOC  BA_VOC   Max_VOC  ...  BA_VKmT   Tot_VKmT    AB_VHT  BA_VHT  \
# ...

# %%
def fill_with_zero(data, columns):
    for column in columns:
        data[column] = data[column].fillna(0)
    return data
